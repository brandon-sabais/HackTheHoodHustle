# %% [markdown]
# <a href="https://colab.research.google.com/github/brandon-sabais/HackTheHoodHustle/blob/main/Mad_Libs(var%2Cinput_review)_Real_Student_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#student
#print "Welcome to Mad Libs!"


#ask user their name


#ask user for adjective1


#ask user for adjective2


#ask user for verb1


#ask user for verb2


#ask user for noun1


#ask user for noun2


#print" Here's your story:"


print("------------------------------------------")

#_________________________________________________________________________
###Concatenation
#Example
#name = "Alice"
#print("Hello, " + name + "!")
#_________________________________________________________________________

#print("There once was a "  adjective1  " programmer named "  name)


#print("who wanted to use Python to "  verb1  " the")


#print("problems in the "  adjective2  " world.")


#print(name + " decided to make a "  noun1  " that")


#print("people could use to "  verb2  " all day long.")


#print("The first thing " name  " wanted to make was")


#print("a "  noun2  ".")


print("------------------------------------------")

#print("Thanks for playing Mad Libs!")
# Out:
# ------------------------------------------
# ------------------------------------------

# %%
# Out:
# Welcome to Mad Libs!
# What is your name? Jazz
# Enter an adjective: love
# Enter another adjective: joy
# Enter a verb: pain
# Enter another verb: be
# Enter a noun: yes
# Enter another noun: chicago
# Here's your story:
# ------------------------------------------
# There once was a love programmer named Jazz
# who wanted to use Python to pain the
# problems in the joy world.
# Jazz decided to make a yes that
# people could use to be all day long.
# The first thing Jazz wanted to make was
# a chicago.
# ------------------------------------------
# Thanks for playing Mad Libs!
